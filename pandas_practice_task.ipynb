# %% [markdown]
# # Pandas Practice Task
#
#
# **Objective:**: Load dataset, clean null values, and visualize article categories using a bar graph.

# %% [markdown]
#  Import Required Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load CSV File

import pandas as pd

df = pd.read_csv(r"C:\Users\Public\Downloads\articles.csv")
print("original data")
print(df)
# Out:
# original data
#    id                      title     category
# 0   1        How to Learn Python  Programming
# 1   2   AI Will Change the World   Technology
# 2   3    Top 10 Python Libraries  Programming
# 3   4        Healthy Living Tips    Lifestyle
# 4   5           New Tech in 2025   Technology
# 5   6       Simple Home Workouts    Lifestyle
# 6   7  Intro to Machine Learning  Programming
# 7   8          Fitness Diet Plan    Lifestyle
# 8   9         Future of Robotics   Technology
# 9  10       Coding for Beginners  Programming

# %%
# Check for null values


print("Null values in each column:")
print(df.isnull().sum())
# Out:
# Null values in each column:
# id          0
# title       0
# category    0
# dtype: int64

# %%
# Remove row with null value

df.dropna(inplace = True)

print(df.to_string())
# Out:
#    id                      title     category
# 0   1        How to Learn Python  Programming
# 1   2   AI Will Change the World   Technology
# 2   3    Top 10 Python Libraries  Programming
# 3   4        Healthy Living Tips    Lifestyle
# 4   5           New Tech in 2025   Technology
# 5   6       Simple Home Workouts    Lifestyle
# 6   7  Intro to Machine Learning  Programming
# 7   8          Fitness Diet Plan    Lifestyle
# 8   9         Future of Robotics   Technology
# 9  10       Coding for Beginners  Programming

# %%
# Show cleaned data


print("\nCleaned Data:")
print(df_cleaned)
# Out:
# Cleaned Data:
#    id                      title     category
# 0   1        How to Learn Python  Programming
# 1   2   AI Will Change the World   Technology
# 2   3    Top 10 Python Libraries  Programming
# 3   4        Healthy Living Tips    Lifestyle
# 4   5           New Tech in 2025   Technology
# 5   6       Simple Home Workouts    Lifestyle
# 6   7  Intro to Machine Learning  Programming
# 7   8          Fitness Diet Plan    Lifestyle
# 8   9         Future of Robotics   Technology
# 9  10       Coding for Beginners  Programming

# %% [markdown]
# # Plot a Bar Graph of Article Categories
#  **Count how many articles are in each category and visualize it.**

# %%
import matplotlib.pyplot as plt

# count articles by category

category_counts = df_cleaned['category'].value_counts()

# Plot bar graph


plt.figure(figsize=(8,5))

category_counts.plot(kind='bar', color='skyblue')

plt.title('Article Categories Count')
plt.xlabel('Category')
plt.ylabel('Number of Articles')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
